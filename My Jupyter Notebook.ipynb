# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Name: **Lennon**
#
# Occupation: Electrical Engineer

# %% [markdown]
# _I am interested in data science because it is a growing field of study and it has a huge possiblilty to provide new insights to existing problems the world is trying to solve through the use of data_

# %% [markdown]
# ### Find the result of 2 Multiply by 2

# %%
2*2
# Out:
# 4

# %% [markdown]
# - one
# - two
# - three
# --------------
# 1. apples
# 2. bananas
# 3. oranges
# ---------------
#
# ~~Strike this out~~
#
# ----------------
#
# | place | Year |
# | ----- | ---- |
# | Paris | 2019 |
# | London | 2018 |
